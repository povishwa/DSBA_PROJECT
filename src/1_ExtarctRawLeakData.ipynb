# %% [markdown]
# NAME  : VISHWAKARMA POOJA RAMASHANKAR
# SR.NO : 00-0-0-40-52-22-1-21633

# %% [markdown]
# Steps performed:
# 1. Manually collected data: water_leakage.xlsx :: Leak id and surrounding 6 meters data from QGIS tool
# i.e. data/water_leakage.xlsx
# 2. Aggregate the data to include the leak ID and all six meter IDs in the dataframe i.e. data/WaterLekageDF.csv
# 3. Divided the Excel workbook into individual sheets with name of each meter ID, where each sheet corresponds to a unique Leak ID, and included a column indicating the meter IDs. i.e. data/SplitMeterIDFiles
# 4. Generated a CSV file for each Leak ID containing comprehensive details such as 'Date', 'Time', 'Flow Rate (mᶾ/hr)', 'Net Flow (mᶾ)', 'Pressure (m)', and 'Meter ID'. i.e. data/RawLeakData

# %%
# Importing libraries
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
from datetime import datetime

# %%
def split_workbook_and_add_meter_id(input_file):
    output_dir = "data/SplitMeterIDFiles"    # Output files
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Reading the Excel file with skipping the first two rows (index 0 and 1) as they contain headers
    xls = pd.ExcelFile(input_file)
    sheet_names = xls.sheet_names
    for sheet_name in sheet_names:
        last_word = sheet_name.split()[-1]
        df = pd.read_excel(input_file, sheet_name=sheet_name, header=1)  # Specifying header row index
        # Adding a new column with Meter ID to the DataFrame
        df['Meter ID'] = last_word
        output_file = os.path.join(output_dir, f"{last_word}.xlsx")
        df.to_excel(output_file, index=False)
        print(f"Sheet '{sheet_name}' saved to '{output_file}' with Meter ID '{last_word}'")

# Provide the path to your input Excel file
input_file = "data/83DMAS.xlsx"
split_workbook_and_add_meter_id(input_file)
print("All sheets processed successfully.")

# Removing the specified files if they exist (data cleaning)
files_to_remove = [
    "data/SplitMeterIDFiles/Byatarayanap.xlsx",
    "data/SplitMeterIDFiles/Nagar.xlsx",
    "data/SplitMeterIDFiles/KRMarketChamarajpeteSW1DM0602.xlsx",
    "data/SplitMeterIDFiles/KRMarketChamarajpeteSW1DM0603.xlsx",
    "data/SplitMeterIDFiles/KRMarketChamarajpeteSW1SM0607.xlsx",
    "data/SplitMeterIDFiles/KRMarketChamarajpeteSW1SM0606.xlsx",
    "data/SplitMeterIDFiles/SW3toSW1.xlsx",
    "data/SplitMeterIDFiles/Sheet33.xlsx"
]

for file in files_to_remove:
    if os.path.exists(file):
        os.remove(file)
        print(f"File '{file}' removed.")
# Out:
# Sheet 'Avalahalli & Byatarayanap' saved to 'data/SplitMeterIDFiles/Byatarayanap.xlsx' with Meter ID 'Byatarayanap'
# Sheet 'Ashok Nagar' saved to 'data/SplitMeterIDFiles/Nagar.xlsx' with Meter ID 'Nagar'
# Sheet 'Ashok Nagar SW3DM0604' saved to 'data/SplitMeterIDFiles/SW3DM0604.xlsx' with Meter ID 'SW3DM0604'
# Sheet 'Ashok Nagar SW3DM0601' saved to 'data/SplitMeterIDFiles/SW3DM0601.xlsx' with Meter ID 'SW3DM0601'
# Sheet 'Ashok Nagar SW3DM0602.' saved to 'data/SplitMeterIDFiles/SW3DM0602..xlsx' with Meter ID 'SW3DM0602.'
# Sheet 'Ashok Nagar SW3DM0603' saved to 'data/SplitMeterIDFiles/SW3DM0603.xlsx' with Meter ID 'SW3DM0603'
# Sheet 'Azad Nagar SW1DM1201' saved to 'data/SplitMeterIDFiles/SW1DM1201.xlsx' with Meter ID 'SW1DM1201'
# Sheet 'Azad Nagar SW1DM1202' saved to 'data/SplitMeterIDFiles/SW1DM1202.xlsx' with Meter ID 'SW1DM1202'
# Sheet 'Azad Nagar SW1DM1203' saved to 'data/SplitMeterIDFiles/SW1DM1203.xlsx' with Meter ID 'SW1DM1203'
# Sheet 'Banagiri Nagar SW2DM0703' saved to 'data/SplitMeterIDFiles/SW2DM0703.xlsx' with Meter ID 'SW2DM0703'
# Sheet 'Banagiri Nagar SW2DM0701' saved to 'data/SplitMeterIDFiles/SW2DM0701.xlsx' with Meter ID 'SW2DM0701'
# Sheet 'Banagiri Nagar SW2DM0702' saved to 'data/SplitMeterIDFiles/SW2DM0702.xlsx' with Meter ID 'SW2DM0702'
# Sheet 'Banashankari2nd stage SW2DM1001' saved to 'data/SplitMeterIDFiles/SW2DM1001.xlsx' with Meter ID 'SW2DM1001'
# Sheet 'Banashankari2nd stage SW2DM1002' saved to 'data/SplitMeterIDFiles/SW2DM1002.xlsx' with Meter ID 'SW2DM1002'
# Sheet 'Banashankari2nd stage SW2DM1003' saved to 'data/SplitMeterIDFiles/SW2DM1003.xlsx' with Meter ID 'SW2DM1003'
# Sheet 'Banashankari2nd stage SW2DM1004' saved to 'data/SplitMeterIDFiles/SW2DM1004.xlsx' with Meter ID 'SW2DM1004'
# Sheet 'Banashankari2nd stage SW2DM1006' saved to 'data/SplitMeterIDFiles/SW2DM1006.xlsx' with Meter ID 'SW2DM1006'
# Sheet 'Banashankari2nd stage SW2DM1005' saved to 'data/SplitMeterIDFiles/SW2DM1005.xlsx' with Meter ID 'SW2DM1005'
# Sheet 'Banashankari2nd stage SW2DM1007' saved to 'data/SplitMeterIDFiles/SW2DM1007.xlsx' with Meter ID 'SW2DM1007'
# Sheet 'Banashankari2nd stage SW2DM1008' saved to 'data/SplitMeterIDFiles/SW2DM1008.xlsx' with Meter ID 'SW2DM1008'
# Sheet 'Basavanagudi SW3DM1001' saved to 'data/SplitMeterIDFiles/SW3DM1001.xlsx' with Meter ID 'SW3DM1001'
# Sheet 'Basavanagudi SW3DM1003' saved to 'data/SplitMeterIDFiles/SW3DM1003.xlsx' with Meter ID 'SW3DM1003'
# Sheet 'Basavangudi SW3toSW1' saved to 'data/SplitMeterIDFiles/SW3toSW1.xlsx' with Meter ID 'SW3toSW1'
# Sheet 'Bandre nagar S1DM0402' saved to 'data/SplitMeterIDFiles/S1DM0402.xlsx' with Meter ID 'S1DM0402'
# Sheet 'Bendre Nagar S1DM0401' saved to 'data/SplitMeterIDFiles/S1DM0401.xlsx' with Meter ID 'S1DM0401'
# Sheet 'Bendre Nagar S1DM0403' saved to 'data/SplitMeterIDFiles/S1DM0403.xlsx' with Meter ID 'S1DM0403'
# Sheet 'BHCS Layout S1DM0701' saved to 'data/SplitMeterIDFiles/S1DM0701.xlsx' with Meter ID 'S1DM0701'
# Sheet 'BHCS Layout  S1DM0702 ' saved to 'data/SplitMeterIDFiles/S1DM0702.xlsx' with Meter ID 'S1DM0702'
# Sheet 'BHCS Layout  S1DM0703' saved to 'data/SplitMeterIDFiles/S1DM0703.xlsx' with Meter ID 'S1DM0703'
# Sheet 'Bhuvaneshwari Nagar SW2DM1601' saved to 'data/SplitMeterIDFiles/SW2DM1601.xlsx' with Meter ID 'SW2DM1601'
# Sheet 'Byrasandra SW4DM0602' saved to 'data/SplitMeterIDFiles/SW4DM0602.xlsx' with Meter ID 'SW4DM0602'
# Sheet 'Byrasandra SW4DM0601' saved to 'data/SplitMeterIDFiles/SW4DM0601.xlsx' with Meter ID 'SW4DM0601'
# Sheet 'Byrasandra SW4DM0603' saved to 'data/SplitMeterIDFiles/SW4DM0603.xlsx' with Meter ID 'SW4DM0603'
# Sheet 'Byrasandra SW4SM0602' saved to 'data/SplitMeterIDFiles/SW4SM0602.xlsx' with Meter ID 'SW4SM0602'
# Sheet 'Byrasandra SW4SM0601' saved to 'data/SplitMeterIDFiles/SW4SM0601.xlsx' with Meter ID 'SW4SM0601'
# Sheet 'CARP Quarters SE3DM0101' saved to 'data/SplitMeterIDFiles/SE3DM0101.xlsx' with Meter ID 'SE3DM0101'
# Sheet 'Chalavadipalya&Chikkal C1DM0101' saved to 'data/SplitMeterIDFiles/C1DM0101.xlsx' with Meter ID 'C1DM0101'
# Sheet 'Chalavadipalya&Chikkal C1DM0102' saved to 'data/SplitMeterIDFiles/C1DM0102.xlsx' with Meter ID 'C1DM0102'
# Sheet 'Chalavadipalya&Chikkal C1DM0103' saved to 'data/SplitMeterIDFiles/C1DM0103.xlsx' with Meter ID 'C1DM0103'
# Sheet 'Chalavadipalya&Chikkal C1DM0107' saved to 'data/SplitMeterIDFiles/C1DM0107.xlsx' with Meter ID 'C1DM0107'
# Sheet 'Channammanakere SW2DM0602' saved to 'data/SplitMeterIDFiles/SW2DM0602.xlsx' with Meter ID 'SW2DM0602'
# Sheet 'Channammanakere SW2DM0603' saved to 'data/SplitMeterIDFiles/SW2DM0603.xlsx' with Meter ID 'SW2DM0603'
# Sheet 'Channammanakere SW2DM0601' saved to 'data/SplitMeterIDFiles/SW2DM0601.xlsx' with Meter ID 'SW2DM0601'
# Sheet 'Channammanakere SW2DM0604' saved to 'data/SplitMeterIDFiles/SW2DM0604.xlsx' with Meter ID 'SW2DM0604'
# Sheet 'Chikkalasandra S1DM0201' saved to 'data/SplitMeterIDFiles/S1DM0201.xlsx' with Meter ID 'S1DM0201'
# Sheet 'Chikkalasandra S1DM0202' saved to 'data/SplitMeterIDFiles/S1DM0202.xlsx' with Meter ID 'S1DM0202'
# Sheet 'Dollars Layout S2DM0101' saved to 'data/SplitMeterIDFiles/S2DM0101.xlsx' with Meter ID 'S2DM0101'
# Sheet 'Dollars Layout S2DM0102' saved to 'data/SplitMeterIDFiles/S2DM0102.xlsx' with Meter ID 'S2DM0102'
# Sheet 'Dwaraka Nagar SW2DM1301' saved to 'data/SplitMeterIDFiles/SW2DM1301.xlsx' with Meter ID 'SW2DM1301'
# Sheet 'Ejipura&RaviTentArea SE3DM1001 ' saved to 'data/SplitMeterIDFiles/SE3DM1001.xlsx' with Meter ID 'SE3DM1001'
# Sheet 'Eshwar Nagar S1DM0501' saved to 'data/SplitMeterIDFiles/S1DM0501.xlsx' with Meter ID 'S1DM0501'
# Sheet 'GandhiBazar&NR Colony SW3DM0903' saved to 'data/SplitMeterIDFiles/SW3DM0903.xlsx' with Meter ID 'SW3DM0903'
# Sheet 'GandhiBazar&NR Colony SW3DM0901' saved to 'data/SplitMeterIDFiles/SW3DM0901.xlsx' with Meter ID 'SW3DM0901'
# Sheet 'GandhiBazar&NRColony SW3toSW1' saved to 'data/SplitMeterIDFiles/SW3toSW1.xlsx' with Meter ID 'SW3toSW1'
# Sheet 'GavipumExt&Hanumanth SW3DM0501 ' saved to 'data/SplitMeterIDFiles/SW3DM0501.xlsx' with Meter ID 'SW3DM0501'
# Sheet 'GavipumExt&Hanumanth SW3DM0502' saved to 'data/SplitMeterIDFiles/SW3DM0502.xlsx' with Meter ID 'SW3DM0502'
# Sheet 'GavipumExt&Hanumanth SW3DM0503' saved to 'data/SplitMeterIDFiles/SW3DM0503.xlsx' with Meter ID 'SW3DM0503'
# Sheet 'GavipumExt&Hanumanth SW3DM0505' saved to 'data/SplitMeterIDFiles/SW3DM0505.xlsx' with Meter ID 'SW3DM0505'
# Sheet 'GavipumExt&Hanumanth SW3DM0506' saved to 'data/SplitMeterIDFiles/SW3DM0506.xlsx' with Meter ID 'SW3DM0506'
# Sheet 'Giri Nagar SW2DM0201' saved to 'data/SplitMeterIDFiles/SW2DM0201.xlsx' with Meter ID 'SW2DM0201'
# Sheet 'Giri Nagar SW2DM0202' saved to 'data/SplitMeterIDFiles/SW2DM0202.xlsx' with Meter ID 'SW2DM0202'
# Sheet 'Giri Nagar SW2DM0204' saved to 'data/SplitMeterIDFiles/SW2DM0204.xlsx' with Meter ID 'SW2DM0204'
# Sheet 'Giri Nagar SW2DM0205' saved to 'data/SplitMeterIDFiles/SW2DM0205.xlsx' with Meter ID 'SW2DM0205'
# Sheet 'Giri Nagar SW2DM0203' saved to 'data/SplitMeterIDFiles/SW2DM0203.xlsx' with Meter ID 'SW2DM0203'
# Sheet 'Gurappana Palya S3DM0601' saved to 'data/SplitMeterIDFiles/S3DM0601.xlsx' with Meter ID 'S3DM0601'
# Sheet 'Gurappana Palya S3DM0602' saved to 'data/SplitMeterIDFiles/S3DM0602.xlsx' with Meter ID 'S3DM0602'
# Sheet 'Gurappana Palya S3DM0603' saved to 'data/SplitMeterIDFiles/S3DM0603.xlsx' with Meter ID 'S3DM0603'
# Sheet 'Gurappana Palya S3DM0604' saved to 'data/SplitMeterIDFiles/S3DM0604.xlsx' with Meter ID 'S3DM0604'
# Sheet 'Gurappana Palya S3DM0605' saved to 'data/SplitMeterIDFiles/S3DM0605.xlsx' with Meter ID 'S3DM0605'
# Sheet 'Gurappana Palya S3SM0601' saved to 'data/SplitMeterIDFiles/S3SM0601.xlsx' with Meter ID 'S3SM0601'
# Sheet 'Gururaj Layout S1DM0101' saved to 'data/SplitMeterIDFiles/S1DM0101.xlsx' with Meter ID 'S1DM0101'
# Sheet 'HombegowdaNagarNorth SW4DM1301 ' saved to 'data/SplitMeterIDFiles/SW4DM1301.xlsx' with Meter ID 'SW4DM1301'
# Sheet 'Hombegowda NagarWest SW4DM1201' saved to 'data/SplitMeterIDFiles/SW4DM1201.xlsx' with Meter ID 'SW4DM1201'
# Sheet 'Hombegowda NagarWest SW4DM1202' saved to 'data/SplitMeterIDFiles/SW4DM1202.xlsx' with Meter ID 'SW4DM1202'
# Sheet 'Hombegowda NagarWest SW4DM1203' saved to 'data/SplitMeterIDFiles/SW4DM1203.xlsx' with Meter ID 'SW4DM1203'
# Sheet 'Hombegowda NagarWest SW4DM1204' saved to 'data/SplitMeterIDFiles/SW4DM1204.xlsx' with Meter ID 'SW4DM1204'
# Sheet 'Hombegowda NagarWest SW4SM1201' saved to 'data/SplitMeterIDFiles/SW4SM1201.xlsx' with Meter ID 'SW4SM1201'
# Sheet 'HombegowdaNagarCent SW4DM0701 ' saved to 'data/SplitMeterIDFiles/SW4DM0701.xlsx' with Meter ID 'SW4DM0701'
# Sheet 'HombegowdaNagarCent SW4SM0701 ' saved to 'data/SplitMeterIDFiles/SW4SM0701.xlsx' with Meter ID 'SW4SM0701'
# Sheet 'HombegowdaNagarCent SW4SM0702' saved to 'data/SplitMeterIDFiles/SW4SM0702.xlsx' with Meter ID 'SW4SM0702'
# Sheet 'Hosakerehalli SW2DM1403' saved to 'data/SplitMeterIDFiles/SW2DM1403.xlsx' with Meter ID 'SW2DM1403'
# Sheet 'Hosakerehalli SW2DM1401' saved to 'data/SplitMeterIDFiles/SW2DM1401.xlsx' with Meter ID 'SW2DM1401'
# Sheet 'Hosakerehalli SW2DM1402' saved to 'data/SplitMeterIDFiles/SW2DM1402.xlsx' with Meter ID 'SW2DM1402'
# Sheet 'IAS Colony S3DM0202' saved to 'data/SplitMeterIDFiles/S3DM0202.xlsx' with Meter ID 'S3DM0202'
# Sheet 'IAS Colony S3DM0201' saved to 'data/SplitMeterIDFiles/S3DM0201.xlsx' with Meter ID 'S3DM0201'
# Sheet 'ISRO Layout S1DM0801' saved to 'data/SplitMeterIDFiles/S1DM0801.xlsx' with Meter ID 'S1DM0801'
# Sheet 'ISRO Layout S1DM0802' saved to 'data/SplitMeterIDFiles/S1DM0802.xlsx' with Meter ID 'S1DM0802'
# Sheet 'ITI Layout SW4DM0901' saved to 'data/SplitMeterIDFiles/SW4DM0901.xlsx' with Meter ID 'SW4DM0901'
# Sheet 'Ittamadu SW2DM1501' saved to 'data/SplitMeterIDFiles/SW2DM1501.xlsx' with Meter ID 'SW2DM1501'
# Sheet 'Ittamadu SW2DM1502' saved to 'data/SplitMeterIDFiles/SW2DM1502.xlsx' with Meter ID 'SW2DM1502'
# Sheet 'J J Nagar SW1DM0903' saved to 'data/SplitMeterIDFiles/SW1DM0903.xlsx' with Meter ID 'SW1DM0903'
# Sheet 'J J Nagar SW1DM0901' saved to 'data/SplitMeterIDFiles/SW1DM0901.xlsx' with Meter ID 'SW1DM0901'
# Sheet 'J J Nagar SW1DM0902' saved to 'data/SplitMeterIDFiles/SW1DM0902.xlsx' with Meter ID 'SW1DM0902'
# Sheet 'J J Nagar SW1SM0903' saved to 'data/SplitMeterIDFiles/SW1SM0903.xlsx' with Meter ID 'SW1SM0903'
# Sheet 'Jakkasandra SE3DM0701' saved to 'data/SplitMeterIDFiles/SE3DM0701.xlsx' with Meter ID 'SE3DM0701'
# Sheet 'Jakkasandra SE3DM0704' saved to 'data/SplitMeterIDFiles/SE3DM0704.xlsx' with Meter ID 'SE3DM0704'
# Sheet 'Jakkasandra SE3DM0702' saved to 'data/SplitMeterIDFiles/SE3DM0702.xlsx' with Meter ID 'SE3DM0702'
# Sheet 'Jakkasandra SE3DM0703' saved to 'data/SplitMeterIDFiles/SE3DM0703.xlsx' with Meter ID 'SE3DM0703'
# Sheet 'Jayanagar 4th Block SW4DM0402' saved to 'data/SplitMeterIDFiles/SW4DM0402.xlsx' with Meter ID 'SW4DM0402'
# Sheet 'Jayanagar 4th Block SW4DM0401' saved to 'data/SplitMeterIDFiles/SW4DM0401.xlsx' with Meter ID 'SW4DM0401'
# Sheet 'Jayanaga 4thTblkS SW4DM1101  ' saved to 'data/SplitMeterIDFiles/SW4DM1101.xlsx' with Meter ID 'SW4DM1101'
# Sheet 'Jayanaga 4thTblkS SW4DM1102 ' saved to 'data/SplitMeterIDFiles/SW4DM1102.xlsx' with Meter ID 'SW4DM1102'
# Sheet 'Jayanaga 4thTblkS SW4DM1103' saved to 'data/SplitMeterIDFiles/SW4DM1103.xlsx' with Meter ID 'SW4DM1103'
# Sheet 'Jayanaga 4thTblkS SW4SM1101' saved to 'data/SplitMeterIDFiles/SW4SM1101.xlsx' with Meter ID 'SW4SM1101'
# Sheet 'Jayanaga 4thTblkS SW4SM1102' saved to 'data/SplitMeterIDFiles/SW4SM1102.xlsx' with Meter ID 'SW4SM1102'
# Sheet 'Jayanaga 4thTblkS SW4SM1103' saved to 'data/SplitMeterIDFiles/SW4SM1103.xlsx' with Meter ID 'SW4SM1103'
# Sheet 'JayanagaR4thTBlk(NE) SW4DM1001 ' saved to 'data/SplitMeterIDFiles/SW4DM1001.xlsx' with Meter ID 'SW4DM1001'
# Sheet 'JayanagaR4thTBlk(NE) SW4DM1002 ' saved to 'data/SplitMeterIDFiles/SW4DM1002.xlsx' with Meter ID 'SW4DM1002'
# Sheet 'JayanagaR4thTBlk(NE) SW4DM1003' saved to 'data/SplitMeterIDFiles/SW4DM1003.xlsx' with Meter ID 'SW4DM1003'
# Sheet 'JayanagaR4thTBlk(NE) SW4DM1004' saved to 'data/SplitMeterIDFiles/SW4DM1004.xlsx' with Meter ID 'SW4DM1004'
# Sheet 'Jayanagar4thTBlkC SW4DM0501' saved to 'data/SplitMeterIDFiles/SW4DM0501.xlsx' with Meter ID 'SW4DM0501'
# Sheet 'Jayanagar4thTBlkC SW4DM0502' saved to 'data/SplitMeterIDFiles/SW4DM0502.xlsx' with Meter ID 'SW4DM0502'
# Sheet 'Jayanagar7thBlk SW2DM1201' saved to 'data/SplitMeterIDFiles/SW2DM1201.xlsx' with Meter ID 'SW2DM1201'
# Sheet 'Jayanagar7thBlk SW2DM1202' saved to 'data/SplitMeterIDFiles/SW2DM1202.xlsx' with Meter ID 'SW2DM1202'
# Sheet 'JP Nagar 1st Phase SW4DM0101' saved to 'data/SplitMeterIDFiles/SW4DM0101.xlsx' with Meter ID 'SW4DM0101'
# Sheet 'JP Nagar 1st Phase SW4DM0102' saved to 'data/SplitMeterIDFiles/SW4DM0102.xlsx' with Meter ID 'SW4DM0102'
# Sheet 'JP Nagar 1st Phase SW4DM0103' saved to 'data/SplitMeterIDFiles/SW4DM0103.xlsx' with Meter ID 'SW4DM0103'
# Sheet 'JP Nagar 2nd Phase SW4DM0201' saved to 'data/SplitMeterIDFiles/SW4DM0201.xlsx' with Meter ID 'SW4DM0201'
# Sheet 'JP Nagar 3rd Phase SW4DM0302' saved to 'data/SplitMeterIDFiles/SW4DM0302.xlsx' with Meter ID 'SW4DM0302'
# Sheet 'JP Nagar 3rd Phase SW4DM0301' saved to 'data/SplitMeterIDFiles/SW4DM0301.xlsx' with Meter ID 'SW4DM0301'
# Sheet 'JP Nagar V Phase S2DM0201' saved to 'data/SplitMeterIDFiles/S2DM0201.xlsx' with Meter ID 'S2DM0201'
# Sheet 'JP Nagar V Phase S2DM0202' saved to 'data/SplitMeterIDFiles/S2DM0202.xlsx' with Meter ID 'S2DM0202'
# Sheet 'JP Nagar V Phase S2DM0203' saved to 'data/SplitMeterIDFiles/S2DM0203.xlsx' with Meter ID 'S2DM0203'
# Sheet 'KRMarketChamarajpeteSW1DM0602  ' saved to 'data/SplitMeterIDFiles/KRMarketChamarajpeteSW1DM0602.xlsx' with Meter ID 'KRMarketChamarajpeteSW1DM0602'
# Sheet 'KRMarketChamarajpeteSW1DM0603' saved to 'data/SplitMeterIDFiles/KRMarketChamarajpeteSW1DM0603.xlsx' with Meter ID 'KRMarketChamarajpeteSW1DM0603'
# Sheet 'KRMarketChamarajpeteSW1SM0607' saved to 'data/SplitMeterIDFiles/KRMarketChamarajpeteSW1SM0607.xlsx' with Meter ID 'KRMarketChamarajpeteSW1SM0607'
# Sheet 'KRMarketChamarajpeteSW1SM0606' saved to 'data/SplitMeterIDFiles/KRMarketChamarajpeteSW1SM0606.xlsx' with Meter ID 'KRMarketChamarajpeteSW1SM0606'
# Sheet 'Kalidasa Layout SW3DM0101' saved to 'data/SplitMeterIDFiles/SW3DM0101.xlsx' with Meter ID 'SW3DM0101'
# Sheet 'Kamkya Layout SW2DM1701' saved to 'data/SplitMeterIDFiles/SW2DM1701.xlsx' with Meter ID 'SW2DM1701'
# Sheet 'Kathriguppe SW2DM0401' saved to 'data/SplitMeterIDFiles/SW2DM0401.xlsx' with Meter ID 'SW2DM0401'
# Sheet 'Kathriguppe SW2DM0404' saved to 'data/SplitMeterIDFiles/SW2DM0404.xlsx' with Meter ID 'SW2DM0404'
# Sheet 'Kathriguppe SW2DM0402' saved to 'data/SplitMeterIDFiles/SW2DM0402.xlsx' with Meter ID 'SW2DM0402'
# Sheet 'Kathriguppe SW2DM0403' saved to 'data/SplitMeterIDFiles/SW2DM0403.xlsx' with Meter ID 'SW2DM0403'
# Sheet 'KG Nagara SW1DM0102' saved to 'data/SplitMeterIDFiles/SW1DM0102.xlsx' with Meter ID 'SW1DM0102'
# Sheet 'KG Nagara SW1DM0103' saved to 'data/SplitMeterIDFiles/SW1DM0103.xlsx' with Meter ID 'SW1DM0103'
# Sheet 'KHB Colony SE3DM0401' saved to 'data/SplitMeterIDFiles/SE3DM0401.xlsx' with Meter ID 'SE3DM0401'
# Sheet 'Koramangala 1st Block SE3DM1201' saved to 'data/SplitMeterIDFiles/SE3DM1201.xlsx' with Meter ID 'SE3DM1201'
# Sheet 'Koramangala 1st Block SE3DM1202' saved to 'data/SplitMeterIDFiles/SE3DM1202.xlsx' with Meter ID 'SE3DM1202'
# Sheet 'Koramangala 3rd & 4th SE3DM0301' saved to 'data/SplitMeterIDFiles/SE3DM0301.xlsx' with Meter ID 'SE3DM0301'
# Sheet 'Koramangala 3rd & 4th SE3DM0302' saved to 'data/SplitMeterIDFiles/SE3DM0302.xlsx' with Meter ID 'SE3DM0302'
# Sheet 'Koramangala 3rd & 4th SE3DM0304' saved to 'data/SplitMeterIDFiles/SE3DM0304.xlsx' with Meter ID 'SE3DM0304'
# Sheet 'Koramangala6thBlk SE3DM0501' saved to 'data/SplitMeterIDFiles/SE3DM0501.xlsx' with Meter ID 'SE3DM0501'
# Sheet 'Koramangala6thBlk SE3DM0502' saved to 'data/SplitMeterIDFiles/SE3DM0502.xlsx' with Meter ID 'SE3DM0502'
# Sheet 'Kormangala 7th & 8th SE3DM1101' saved to 'data/SplitMeterIDFiles/SE3DM1101.xlsx' with Meter ID 'SE3DM1101'
# Sheet 'Kormangala 7th & 8th SE3DM0201' saved to 'data/SplitMeterIDFiles/SE3DM0201.xlsx' with Meter ID 'SE3DM0201'
# Sheet 'Kormangala 7th & 8th SE3DM0202' saved to 'data/SplitMeterIDFiles/SE3DM0202.xlsx' with Meter ID 'SE3DM0202'
# Sheet 'KSRP Quarters SE3DM1301' saved to 'data/SplitMeterIDFiles/SE3DM1301.xlsx' with Meter ID 'SE3DM1301'
# Sheet 'Kumarswamy Layout 1st S1DM0901' saved to 'data/SplitMeterIDFiles/S1DM0901.xlsx' with Meter ID 'S1DM0901'
# Sheet 'Kumarswamy Layout 1st S1DM0902' saved to 'data/SplitMeterIDFiles/S1DM0902.xlsx' with Meter ID 'S1DM0902'
# Sheet 'Kumarswamy Layout 2nd S1DM0601' saved to 'data/SplitMeterIDFiles/S1DM0601.xlsx' with Meter ID 'S1DM0601'
# Sheet 'Kuvempu Nagar S3DM0301' saved to 'data/SplitMeterIDFiles/S3DM0301.xlsx' with Meter ID 'S3DM0301'
# Sheet 'Kuvempu Nagar S3DM0302' saved to 'data/SplitMeterIDFiles/S3DM0302.xlsx' with Meter ID 'S3DM0302'
# Sheet 'Kuvempu Nagar S3DM0303' saved to 'data/SplitMeterIDFiles/S3DM0303.xlsx' with Meter ID 'S3DM0303'
# Sheet 'Madiwala S3DM0101' saved to 'data/SplitMeterIDFiles/S3DM0101.xlsx' with Meter ID 'S3DM0101'
# Sheet 'Madiwala S3DM0102' saved to 'data/SplitMeterIDFiles/S3DM0102.xlsx' with Meter ID 'S3DM0102'
# Sheet 'Maruthi Nagar S3DM0901' saved to 'data/SplitMeterIDFiles/S3DM0901.xlsx' with Meter ID 'S3DM0901'
# Sheet 'Mavalli SW1DM0501' saved to 'data/SplitMeterIDFiles/SW1DM0501.xlsx' with Meter ID 'SW1DM0501'
# Sheet 'Mavalli SW1DM0502' saved to 'data/SplitMeterIDFiles/SW1DM0502.xlsx' with Meter ID 'SW1DM0502'
# Sheet 'Mico Layout S3DM0401' saved to 'data/SplitMeterIDFiles/S3DM0401.xlsx' with Meter ID 'S3DM0401'
# Sheet 'Muneshwara Block SW3DM0704' saved to 'data/SplitMeterIDFiles/SW3DM0704.xlsx' with Meter ID 'SW3DM0704'
# Sheet 'Muneshwara Block SW3DM0702' saved to 'data/SplitMeterIDFiles/SW3DM0702.xlsx' with Meter ID 'SW3DM0702'
# Sheet 'Muneshwara Block SW3DM0701' saved to 'data/SplitMeterIDFiles/SW3DM0701.xlsx' with Meter ID 'SW3DM0701'
# Sheet 'Nagendra Block SW3DM0401' saved to 'data/SplitMeterIDFiles/SW3DM0401.xlsx' with Meter ID 'SW3DM0401'
# Sheet 'Nagendra Block SW3DM0402' saved to 'data/SplitMeterIDFiles/SW3DM0402.xlsx' with Meter ID 'SW3DM0402'
# Sheet 'New Timber Yard  W1DMA0202' saved to 'data/SplitMeterIDFiles/W1DMA0202.xlsx' with Meter ID 'W1DMA0202'
# Sheet 'New Timber Yard  W1DMA0201' saved to 'data/SplitMeterIDFiles/W1DMA0201.xlsx' with Meter ID 'W1DMA0201'
# Sheet 'New Timber Yard  W1DMA0203' saved to 'data/SplitMeterIDFiles/W1DMA0203.xlsx' with Meter ID 'W1DMA0203'
# Sheet 'New Timber Yard  W1DMA0204' saved to 'data/SplitMeterIDFiles/W1DMA0204.xlsx' with Meter ID 'W1DMA0204'
# Sheet 'Newguddadahalli W1DM0102' saved to 'data/SplitMeterIDFiles/W1DM0102.xlsx' with Meter ID 'W1DM0102'
# Sheet 'Newguddadahalli W1DM0103' saved to 'data/SplitMeterIDFiles/W1DM0103.xlsx' with Meter ID 'W1DM0103'
# Sheet 'Newguddadahalli W1DM0101' saved to 'data/SplitMeterIDFiles/W1DM0101.xlsx' with Meter ID 'W1DM0101'
# Sheet 'Old Guddadahalli SW1DM1001' saved to 'data/SplitMeterIDFiles/SW1DM1001.xlsx' with Meter ID 'SW1DM1001'
# Sheet 'Old Guddadahalli SW1DM1002' saved to 'data/SplitMeterIDFiles/SW1DM1002.xlsx' with Meter ID 'SW1DM1002'
# Sheet 'Padmanabhanaga S1DM0301' saved to 'data/SplitMeterIDFiles/S1DM0301.xlsx' with Meter ID 'S1DM0301'
# Sheet 'Padmanabhanagar S1DM0302 ' saved to 'data/SplitMeterIDFiles/S1DM0302.xlsx' with Meter ID 'S1DM0302'
# Sheet 'Pragathipura S1DM1001' saved to 'data/SplitMeterIDFiles/S1DM1001.xlsx' with Meter ID 'S1DM1001'
# Sheet 'Pragathipura S1DM1002' saved to 'data/SplitMeterIDFiles/S1DM1002.xlsx' with Meter ID 'S1DM1002'
# Sheet 'Pragathipura S1DM1003' saved to 'data/SplitMeterIDFiles/S1DM1003.xlsx' with Meter ID 'S1DM1003'
# Sheet 'Raghavendra Block SW3DM0201' saved to 'data/SplitMeterIDFiles/SW3DM0201.xlsx' with Meter ID 'SW3DM0201'
# Sheet 'Shakambari Nagar SW4DM0801' saved to 'data/SplitMeterIDFiles/SW4DM0801.xlsx' with Meter ID 'SW4DM0801'
# Sheet 'Shakambari Nagar SW4DM0802' saved to 'data/SplitMeterIDFiles/SW4DM0802.xlsx' with Meter ID 'SW4DM0802'
# Sheet 'Shakambari Nagar SW4SM0801' saved to 'data/SplitMeterIDFiles/SW4SM0801.xlsx' with Meter ID 'SW4SM0801'
# Sheet 'Shastri Nagar SW2DM1101' saved to 'data/SplitMeterIDFiles/SW2DM1101.xlsx' with Meter ID 'SW2DM1101'
# Sheet 'Shastri Nagar SW2DM1102' saved to 'data/SplitMeterIDFiles/SW2DM1102.xlsx' with Meter ID 'SW2DM1102'
# Sheet 'Shastri Nagar SW2DM1103' saved to 'data/SplitMeterIDFiles/SW2DM1103.xlsx' with Meter ID 'SW2DM1103'
# Sheet 'Siddhartha Colony SE3DM0802' saved to 'data/SplitMeterIDFiles/SE3DM0802.xlsx' with Meter ID 'SE3DM0802'
# Sheet 'Siddhartha Colony SE3DM0801' saved to 'data/SplitMeterIDFiles/SE3DM0801.xlsx' with Meter ID 'SE3DM0801'
# Sheet 'Siddhartha Colony SE3BM0801' saved to 'data/SplitMeterIDFiles/SE3BM0801.xlsx' with Meter ID 'SE3BM0801'
# Sheet 'Siddhartha Colony SE3BM0802' saved to 'data/SplitMeterIDFiles/SE3BM0802.xlsx' with Meter ID 'SE3BM0802'
# Sheet 'Siddhartha Colony SE3BM0803' saved to 'data/SplitMeterIDFiles/SE3BM0803.xlsx' with Meter ID 'SE3BM0803'
# Sheet 'Srinagar SW3DM0301' saved to 'data/SplitMeterIDFiles/SW3DM0301.xlsx' with Meter ID 'SW3DM0301'
# Sheet 'Srinagar SW3DM0302' saved to 'data/SplitMeterIDFiles/SW3DM0302.xlsx' with Meter ID 'SW3DM0302'
# Sheet 'Srinagar SW3DM0303' saved to 'data/SplitMeterIDFiles/SW3DM0303.xlsx' with Meter ID 'SW3DM0303'
# Sheet 'Srinivasa Nagar SW2DM0302.' saved to 'data/SplitMeterIDFiles/SW2DM0302..xlsx' with Meter ID 'SW2DM0302.'
# Sheet 'Sheet33' saved to 'data/SplitMeterIDFiles/Sheet33.xlsx' with Meter ID 'Sheet33'
# Sheet 'Srinivasa Nagar SW2DM0304' saved to 'data/SplitMeterIDFiles/SW2DM0304.xlsx' with Meter ID 'SW2DM0304'
# Sheet 'Srinivasa Nagar SW2DM0301' saved to 'data/SplitMeterIDFiles/SW2DM0301.xlsx' with Meter ID 'SW2DM0301'
# Sheet 'Srinivasa Nagar SW2DM0303' saved to 'data/SplitMeterIDFiles/SW2DM0303.xlsx' with Meter ID 'SW2DM0303'
# Sheet 'STB SE3DM0601' saved to 'data/SplitMeterIDFiles/SE3DM0601.xlsx' with Meter ID 'SE3DM0601'
# Sheet 'STB SE3DM0602' saved to 'data/SplitMeterIDFiles/SE3DM0602.xlsx' with Meter ID 'SE3DM0602'
# Sheet 'Suddagunte Palya S3DM0804 ' saved to 'data/SplitMeterIDFiles/S3DM0804.xlsx' with Meter ID 'S3DM0804'
# Sheet 'Suddagunte Palya S3DM0803' saved to 'data/SplitMeterIDFiles/S3DM0803.xlsx' with Meter ID 'S3DM0803'
# Sheet 'Suddagunte Palya S3DM0802' saved to 'data/SplitMeterIDFiles/S3DM0802.xlsx' with Meter ID 'S3DM0802'
# Sheet 'Suddagunte Palya S3DM0801' saved to 'data/SplitMeterIDFiles/S3DM0801.xlsx' with Meter ID 'S3DM0801'
# Sheet 'Suddagunte Palya S3DM0805' saved to 'data/SplitMeterIDFiles/S3DM0805.xlsx' with Meter ID 'S3DM0805'
# Sheet 'Thyagaraja Nagar SW3DM1301' saved to 'data/SplitMeterIDFiles/SW3DM1301.xlsx' with Meter ID 'SW3DM1301'
# Sheet 'Thyagaraja Nagar SW3DM1302' saved to 'data/SplitMeterIDFiles/SW3DM1302.xlsx' with Meter ID 'SW3DM1302'
# Sheet 'Thyagaraja Nagar SW3DM1303' saved to 'data/SplitMeterIDFiles/SW3DM1303.xlsx' with Meter ID 'SW3DM1303'
# Sheet 'Thyagaraja Nagar SW3DM1304' saved to 'data/SplitMeterIDFiles/SW3DM1304.xlsx' with Meter ID 'SW3DM1304'
# Sheet 'Thyagaraja Nagar SW3DM1306' saved to 'data/SplitMeterIDFiles/SW3DM1306.xlsx' with Meter ID 'SW3DM1306'
# Sheet 'Thyagaraja Nagar SW3DM1308' saved to 'data/SplitMeterIDFiles/SW3DM1308.xlsx' with Meter ID 'SW3DM1308'
# Sheet 'V V Puram SW1DM0402' saved to 'data/SplitMeterIDFiles/SW1DM0402.xlsx' with Meter ID 'SW1DM0402'
# Sheet 'V V Puram SW1DM0403' saved to 'data/SplitMeterIDFiles/SW1DM0403.xlsx' with Meter ID 'SW1DM0403'
# Sheet 'V V Puram SW1DM0405' saved to 'data/SplitMeterIDFiles/SW1DM0405.xlsx' with Meter ID 'SW1DM0405'
# Sheet 'Venkateshwar Layout S3DM0501' saved to 'data/SplitMeterIDFiles/S3DM0501.xlsx' with Meter ID 'S3DM0501'
# Sheet 'Venkateshwar Layout S3DM0502' saved to 'data/SplitMeterIDFiles/S3DM0502.xlsx' with Meter ID 'S3DM0502'
# Sheet 'Venkateshwar Layout S3DM0503' saved to 'data/SplitMeterIDFiles/S3DM0503.xlsx' with Meter ID 'S3DM0503'
# Sheet 'Vidya Nagar SW2DM0102' saved to 'data/SplitMeterIDFiles/SW2DM0102.xlsx' with Meter ID 'SW2DM0102'
# Sheet 'Vidya Nagar SW2DM0101' saved to 'data/SplitMeterIDFiles/SW2DM0101.xlsx' with Meter ID 'SW2DM0101'
# Sheet 'Vivekananda Nagar SW2DM0501' saved to 'data/SplitMeterIDFiles/SW2DM0501.xlsx' with Meter ID 'SW2DM0501'
# Sheet 'Venkateshwar Layout S3SM0501' saved to 'data/SplitMeterIDFiles/S3SM0501.xlsx' with Meter ID 'S3SM0501'
# All sheets processed successfully.
# File 'data/SplitMeterIDFiles/Byatarayanap.xlsx' removed.
# File 'data/SplitMeterIDFiles/Nagar.xlsx' removed.
# File 'data/SplitMeterIDFiles/KRMarketChamarajpeteSW1DM0602.xlsx' removed.
# File 'data/SplitMeterIDFiles/KRMarketChamarajpeteSW1DM0603.xlsx' removed.
# File 'data/SplitMeterIDFiles/KRMarketChamarajpeteSW1SM0607.xlsx' removed.
# File 'data/SplitMeterIDFiles/KRMarketChamarajpeteSW1SM0606.xlsx' removed.
# File 'data/SplitMeterIDFiles/SW3toSW1.xlsx' removed.
# File 'data/SplitMeterIDFiles/Sheet33.xlsx' removed.

# %%
# Manually collected data :: Leak id and surrounding 6 meters data from QGIS tool 
# i.e. data/water_leakage.xlsx

df = pd.read_excel("data/water_leakage.xlsx")
WaterLekageDF = pd.DataFrame(df[["id", "date_leak_", "meter_1", "meter_2", "meter_3", "meter_4", "meter_5", "meter_6"]])
# Dropping duplicate rows based on 'id' column
WaterLekageDF.drop_duplicates(subset='id', inplace=True)
#print(WaterLekageDF)

input_format = "%Y-%m-%d %I:%M %p"
output_format = "%Y-%m-%d %H:%M:%S"

def convert_date(date_str):
    if isinstance(date_str, str):
        date_str = date_str.upper()
        # Replace "A.M." and "P.M." with "AM" and "PM" respectively
        date_str = date_str.replace(" A.M.", " AM").replace(" P.M.", " PM")
        # Parsing the date string into a datetime object
        date_obj = datetime.strptime(date_str, input_format)
        formatted_date = date_obj.strftime(output_format)
        return formatted_date
    else:
        return date_str
WaterLekageDF['date_leak_'] = WaterLekageDF['date_leak_'].apply(lambda x: convert_date(x))
# print(WaterLekageDF['date_leak_'])
WaterLekageDF['date_leak_'] = pd.to_datetime(WaterLekageDF['date_leak_'])
WaterLekageDF.insert(2, 'time', WaterLekageDF['date_leak_'].dt.strftime('%H:%M:%S'))
# Saving the DataFrame to a CSV file
WaterLekageDF.to_csv("data/WaterLekageDF.csv", index=False)
WaterLekageDF
# Out:
#      id          date_leak_      time    meter_1    meter_2    meter_3  \
# 0   776 2017-11-12 03:58:00  03:58:00   S1DM0301   S1DM0501   S1DM0401
# 1  5119 2018-02-02 10:58:00  10:58:00  SW2DM0601  SW2DM0301  SW2DM0602
# 2   494 2017-11-08 09:56:00  09:56:00  SW4SM1103  SW4DM0502  SW4DM1102
# 3   763 2017-11-11 14:15:00  14:15:00   S3DM0801   S3DM0604  SW4DM1103
# 4  4210 2018-01-11 13:55:00  13:55:00  SE3DM0703  SE3DM0702  SE3DM0701
# 5  4030 2018-01-08 15:13:00  15:13:00  SE3DM0301  SE3DM0302  SE3DM0802
# 6  7500 2018-03-27 17:24:00  17:24:00  SW3DM0401  SW3DM0402  SW3DM0702
#
#      meter_4    meter_5    meter_6
# 0   S1DM0402  SW2DM1002   S1DM0403
# 1  SW2DM0501  SW3DM0603  SW2DM0603
# 2  SW4SM1102  SW4DM0301  SW4SM1101
# 3   S3DM0603   S3DM0503   S3DM0802
# 4  SE3DM1202  SE3DM1301  SE3DM0704
# 5  SE3DM0801   S3DM0901  SE3BM0801
# 6  SW3DM0201  SW3DM0303  SW3DM0301

# %%
# Load the WaterLekageDF.csv dataframe
water_leakage_df = pd.read_csv("data/WaterLekageDF.csv")

# Iterate over each unique leak ID
for index, row in water_leakage_df.iterrows():
    concatenated_df = pd.DataFrame()
    # Extracting meter IDs associated with the current leak ID
    meter_ids = row[['meter_1', 'meter_2', 'meter_3', 'meter_4', 'meter_5', 'meter_6']].values
    meter_ids = [meter_id for meter_id in meter_ids if pd.notnull(meter_id)]  # Remove null values
    print(f"Leak ID: {row['id']}, Meter IDs: {meter_ids}") # Printing leak ID and associated meter IDs
    directory = "data/SplitMeterIDFiles"
    # Iterate over each meter ID associated with the current leak ID
    for meter_id in meter_ids:
        file_path = os.path.join(directory, f"{meter_id}.xlsx")   # Constructing the file path
        if os.path.exists(file_path):  # Checking if the file exists
            print(f"Reading data from {file_path}")
            df = pd.read_excel(file_path)
            df = df.iloc[1:].reset_index(drop=True)  # Drop the first row
            df.columns = ['Date', 'Time', 'Flow Rate (mᶾ/hr)', 'Net Flow (mᶾ)', 'Pressure (m)', 'Meter ID']  # Assign new column names
            concatenated_df = pd.concat([concatenated_df, df], axis=0, ignore_index=True)
            
        else:
            print(f"File {file_path} not found.")
    concatenated_df.insert(0, 'Leak ID', index+1)
    output_directory = "data/RawLeakData"
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)
    
    output_csv_path = os.path.join(output_directory, f"{row['id']}.csv")
    concatenated_df.to_csv(output_csv_path, index=False)

    print(f"Concatenated meter data for leak {row['id']} saved to:", output_csv_path)
# Out:
# Leak ID: 776, Meter IDs: ['S1DM0301', 'S1DM0501', 'S1DM0401', 'S1DM0402', 'SW2DM1002', 'S1DM0403']
# Reading data from data/SplitMeterIDFiles/S1DM0301.xlsx
# Reading data from data/SplitMeterIDFiles/S1DM0501.xlsx
# Reading data from data/SplitMeterIDFiles/S1DM0401.xlsx
# Reading data from data/SplitMeterIDFiles/S1DM0402.xlsx
# Reading data from data/SplitMeterIDFiles/SW2DM1002.xlsx
# Reading data from data/SplitMeterIDFiles/S1DM0403.xlsx
# Concatenated meter data for leak 776 saved to: data/RawLeakData/776.csv
# Leak ID: 5119, Meter IDs: ['SW2DM0601', 'SW2DM0301', 'SW2DM0602', 'SW2DM0501', 'SW3DM0603', 'SW2DM0603']
# Reading data from data/SplitMeterIDFiles/SW2DM0601.xlsx
# Reading data from data/SplitMeterIDFiles/SW2DM0301.xlsx
# Reading data from data/SplitMeterIDFiles/SW2DM0602.xlsx
# Reading data from data/SplitMeterIDFiles/SW2DM0501.xlsx
# Reading data from data/SplitMeterIDFiles/SW3DM0603.xlsx
# Reading data from data/SplitMeterIDFiles/SW2DM0603.xlsx
# Concatenated meter data for leak 5119 saved to: data/RawLeakData/5119.csv
# Leak ID: 494, Meter IDs: ['SW4SM1103', 'SW4DM0502', 'SW4DM1102', 'SW4SM1102', 'SW4DM0301', 'SW4SM1101']
# Reading data from data/SplitMeterIDFiles/SW4SM1103.xlsx
# Reading data from data/SplitMeterIDFiles/SW4DM0502.xlsx
# Reading data from data/SplitMeterIDFiles/SW4DM1102.xlsx
# Reading data from data/SplitMeterIDFiles/SW4SM1102.xlsx
# Reading data from data/SplitMeterIDFiles/SW4DM0301.xlsx
# Reading data from data/SplitMeterIDFiles/SW4SM1101.xlsx
# Concatenated meter data for leak 494 saved to: data/RawLeakData/494.csv
# Leak ID: 763, Meter IDs: ['S3DM0801', 'S3DM0604', 'SW4DM1103', 'S3DM0603', 'S3DM0503', 'S3DM0802']
# Reading data from data/SplitMeterIDFiles/S3DM0801.xlsx
# Reading data from data/SplitMeterIDFiles/S3DM0604.xlsx
# Reading data from data/SplitMeterIDFiles/SW4DM1103.xlsx
# Reading data from data/SplitMeterIDFiles/S3DM0603.xlsx
# Reading data from data/SplitMeterIDFiles/S3DM0503.xlsx
# Reading data from data/SplitMeterIDFiles/S3DM0802.xlsx
# Concatenated meter data for leak 763 saved to: data/RawLeakData/763.csv
# Leak ID: 4210, Meter IDs: ['SE3DM0703', 'SE3DM0702', 'SE3DM0701', 'SE3DM1202', 'SE3DM1301', 'SE3DM0704']
# Reading data from data/SplitMeterIDFiles/SE3DM0703.xlsx
# Reading data from data/SplitMeterIDFiles/SE3DM0702.xlsx
# Reading data from data/SplitMeterIDFiles/SE3DM0701.xlsx
# Reading data from data/SplitMeterIDFiles/SE3DM1202.xlsx
# Reading data from data/SplitMeterIDFiles/SE3DM1301.xlsx
# Reading data from data/SplitMeterIDFiles/SE3DM0704.xlsx
# Concatenated meter data for leak 4210 saved to: data/RawLeakData/4210.csv
# Leak ID: 4030, Meter IDs: ['SE3DM0301', 'SE3DM0302', 'SE3DM0802', 'SE3DM0801', 'S3DM0901', 'SE3BM0801']
# Reading data from data/SplitMeterIDFiles/SE3DM0301.xlsx
# Reading data from data/SplitMeterIDFiles/SE3DM0302.xlsx
# Reading data from data/SplitMeterIDFiles/SE3DM0802.xlsx
# Reading data from data/SplitMeterIDFiles/SE3DM0801.xlsx
# Reading data from data/SplitMeterIDFiles/S3DM0901.xlsx
# Reading data from data/SplitMeterIDFiles/SE3BM0801.xlsx
# Concatenated meter data for leak 4030 saved to: data/RawLeakData/4030.csv
# Leak ID: 7500, Meter IDs: ['SW3DM0401', 'SW3DM0402', 'SW3DM0702', 'SW3DM0201', 'SW3DM0303', 'SW3DM0301']
# Reading data from data/SplitMeterIDFiles/SW3DM0401.xlsx
# Reading data from data/SplitMeterIDFiles/SW3DM0402.xlsx
# Reading data from data/SplitMeterIDFiles/SW3DM0702.xlsx
# Reading data from data/SplitMeterIDFiles/SW3DM0201.xlsx
# Reading data from data/SplitMeterIDFiles/SW3DM0303.xlsx
# Reading data from data/SplitMeterIDFiles/SW3DM0301.xlsx
# Concatenated meter data for leak 7500 saved to: data/RawLeakData/7500.csv
